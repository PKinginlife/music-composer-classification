# %%
# !unzip Composer_Dataset.zip
# Out:
# Archive:  Composer_Dataset.zip
#    creating: Composer_Dataset/
#   inflating: __MACOSX/._Composer_Dataset
#   inflating: Composer_Dataset/.DS_Store
#   inflating: __MACOSX/Composer_Dataset/._.DS_Store
#    creating: Composer_Dataset/NN_midi_files_extended/
#   inflating: __MACOSX/Composer_Dataset/._NN_midi_files_extended
#   inflating: Composer_Dataset/NN_midi_files_extended/.DS_Store
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/._.DS_Store
#    creating: Composer_Dataset/NN_midi_files_extended/test/
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/._test
#    creating: Composer_Dataset/NN_midi_files_extended/train/
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/._train
#    creating: Composer_Dataset/NN_midi_files_extended/dev/
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/._dev
#    creating: Composer_Dataset/NN_midi_files_extended/test/mozart/
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/test/._mozart
#    creating: Composer_Dataset/NN_midi_files_extended/test/chopin/
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/test/._chopin
#    creating: Composer_Dataset/NN_midi_files_extended/test/handel/
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/test/._handel
#   inflating: Composer_Dataset/NN_midi_files_extended/test/.DS_Store
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/test/._.DS_Store
#    creating: Composer_Dataset/NN_midi_files_extended/test/byrd/
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/test/._byrd
#    creating: Composer_Dataset/NN_midi_files_extended/test/schumann/
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/test/._schumann
#    creating: Composer_Dataset/NN_midi_files_extended/test/mendelssohn/
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/test/._mendelssohn
#    creating: Composer_Dataset/NN_midi_files_extended/test/hummel/
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/test/._hummel
#    creating: Composer_Dataset/NN_midi_files_extended/test/bach/
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/test/._bach
#    creating: Composer_Dataset/NN_midi_files_extended/test/bartok/
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/test/._bartok
#    creating: Composer_Dataset/NN_midi_files_extended/train/mozart/
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/._mozart
#    creating: Composer_Dataset/NN_midi_files_extended/train/chopin/
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/._chopin
#    creating: Composer_Dataset/NN_midi_files_extended/train/handel/
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/._handel
#   inflating: Composer_Dataset/NN_midi_files_extended/train/.DS_Store
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/._.DS_Store
#    creating: Composer_Dataset/NN_midi_files_extended/train/byrd/
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/._byrd
#    creating: Composer_Dataset/NN_midi_files_extended/train/schumann/
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/._schumann
#    creating: Composer_Dataset/NN_midi_files_extended/train/mendelssohn/
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/._mendelssohn
#    creating: Composer_Dataset/NN_midi_files_extended/train/hummel/
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/._hummel
#    creating: Composer_Dataset/NN_midi_files_extended/train/bach/
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/._bach
#    creating: Composer_Dataset/NN_midi_files_extended/train/bartok/
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/._bartok
#    creating: Composer_Dataset/NN_midi_files_extended/dev/mozart/
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/dev/._mozart
#    creating: Composer_Dataset/NN_midi_files_extended/dev/chopin/
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/dev/._chopin
#    creating: Composer_Dataset/NN_midi_files_extended/dev/handel/
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/dev/._handel
#   inflating: Composer_Dataset/NN_midi_files_extended/dev/.DS_Store
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/dev/._.DS_Store
#    creating: Composer_Dataset/NN_midi_files_extended/dev/byrd/
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/dev/._byrd
#    creating: Composer_Dataset/NN_midi_files_extended/dev/schumann/
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/dev/._schumann
#    creating: Composer_Dataset/NN_midi_files_extended/dev/mendelssohn/
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/dev/._mendelssohn
#    creating: Composer_Dataset/NN_midi_files_extended/dev/hummel/
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/dev/._hummel
#    creating: Composer_Dataset/NN_midi_files_extended/dev/bach/
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/dev/._bach
#    creating: Composer_Dataset/NN_midi_files_extended/dev/bartok/
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/dev/._bartok
#   inflating: Composer_Dataset/NN_midi_files_extended/test/mozart/.DS_Store
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/test/mozart/._.DS_Store
#   inflating: Composer_Dataset/NN_midi_files_extended/test/mozart/mozart014.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/test/mozart/._mozart014.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/test/mozart/mozart038.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/test/mozart/._mozart038.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/test/mozart/mozart004.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/test/mozart/._mozart004.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/test/mozart/mozart025.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/test/mozart/._mozart025.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/test/chopin/.DS_Store
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/test/chopin/._.DS_Store
#   inflating: Composer_Dataset/NN_midi_files_extended/test/chopin/chopin053.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/test/chopin/._chopin053.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/test/chopin/chopin086.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/test/chopin/._chopin086.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/test/chopin/chopin078.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/test/chopin/._chopin078.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/test/chopin/chopin062.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/test/chopin/._chopin062.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/test/handel/handel107.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/test/handel/._handel107.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/test/handel/handel112.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/test/handel/._handel112.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/test/handel/.DS_Store
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/test/handel/._.DS_Store
#   inflating: Composer_Dataset/NN_midi_files_extended/test/handel/handel147.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/test/handel/._handel147.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/test/handel/handel137.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/test/handel/._handel137.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/test/byrd/.DS_Store
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/test/byrd/._.DS_Store
#   inflating: Composer_Dataset/NN_midi_files_extended/test/byrd/byrd150.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/test/byrd/._byrd150.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/test/byrd/byrd151.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/test/byrd/._byrd151.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/test/byrd/byrd176.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/test/byrd/._byrd176.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/test/byrd/byrd174.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/test/byrd/._byrd174.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/test/schumann/.DS_Store
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/test/schumann/._.DS_Store
#   inflating: Composer_Dataset/NN_midi_files_extended/test/schumann/schumann205.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/test/schumann/._schumann205.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/test/schumann/schumann240.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/test/schumann/._schumann240.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/test/schumann/schumann220.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/test/schumann/._schumann220.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/test/mendelssohn/mendelssohn288.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/test/mendelssohn/._mendelssohn288.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/test/mendelssohn/.DS_Store
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/test/mendelssohn/._.DS_Store
#   inflating: Composer_Dataset/NN_midi_files_extended/test/mendelssohn/mendelssohn259.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/test/mendelssohn/._mendelssohn259.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/test/mendelssohn/mendelssohn282.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/test/mendelssohn/._mendelssohn282.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/test/mendelssohn/mendelssohn284.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/test/mendelssohn/._mendelssohn284.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/test/hummel/hummel304.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/test/hummel/._hummel304.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/test/hummel/.DS_Store
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/test/hummel/._.DS_Store
#   inflating: Composer_Dataset/NN_midi_files_extended/test/hummel/hummel314.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/test/hummel/._hummel314.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/test/hummel/hummel323.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/test/hummel/._hummel323.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/test/hummel/hummel335.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/test/hummel/._hummel335.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/test/bach/bach376.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/test/bach/._bach376.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/test/bach/bach349.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/test/bach/._bach349.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/test/bach/.DS_Store
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/test/bach/._.DS_Store
#   inflating: Composer_Dataset/NN_midi_files_extended/test/bach/bach359.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/test/bach/._bach359.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/test/bach/bach356.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/test/bach/._bach356.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/test/bartok/.DS_Store
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/test/bartok/._.DS_Store
#   inflating: Composer_Dataset/NN_midi_files_extended/test/bartok/bartok392.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/test/bartok/._bartok392.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/test/bartok/bartok438.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/test/bartok/._bartok438.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/test/bartok/bartok429.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/test/bartok/._bartok429.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/test/bartok/bartok400.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/test/bartok/._bartok400.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/mozart/mozart048.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/mozart/._mozart048.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/mozart/.DS_Store
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/mozart/._.DS_Store
#   inflating: Composer_Dataset/NN_midi_files_extended/train/mozart/mozart028.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/mozart/._mozart028.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/mozart/mozart000.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/mozart/._mozart000.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/mozart/mozart001.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/mozart/._mozart001.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/mozart/mozart015.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/mozart/._mozart015.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/mozart/mozart029.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/mozart/._mozart029.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/mozart/mozart003.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/mozart/._mozart003.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/mozart/mozart017.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/mozart/._mozart017.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/mozart/mozart016.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/mozart/._mozart016.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/mozart/mozart002.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/mozart/._mozart002.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/mozart/mozart006.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/mozart/._mozart006.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/mozart/mozart012.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/mozart/._mozart012.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/mozart/mozart013.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/mozart/._mozart013.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/mozart/mozart007.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/mozart/._mozart007.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/mozart/mozart011.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/mozart/._mozart011.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/mozart/mozart005.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/mozart/._mozart005.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/mozart/mozart010.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/mozart/._mozart010.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/mozart/mozart009.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/mozart/._mozart009.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/mozart/mozart021.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/mozart/._mozart021.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/mozart/mozart034.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/mozart/._mozart034.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/mozart/mozart008.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/mozart/._mozart008.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/mozart/mozart022.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/mozart/._mozart022.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/mozart/mozart036.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/mozart/._mozart036.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/mozart/mozart037.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/mozart/._mozart037.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/mozart/mozart023.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/mozart/._mozart023.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/mozart/mozart027.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/mozart/._mozart027.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/mozart/mozart033.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/mozart/._mozart033.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/mozart/mozart032.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/mozart/._mozart032.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/mozart/mozart026.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/mozart/._mozart026.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/mozart/mozart030.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/mozart/._mozart030.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/mozart/mozart024.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/mozart/._mozart024.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/mozart/mozart018.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/mozart/._mozart018.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/mozart/mozart019.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/mozart/._mozart019.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/mozart/mozart031.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/mozart/._mozart031.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/mozart/mozart042.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/mozart/._mozart042.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/mozart/mozart043.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/mozart/._mozart043.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/mozart/mozart041.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/mozart/._mozart041.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/mozart/mozart044.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/mozart/._mozart044.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/mozart/mozart045.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/mozart/._mozart045.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/mozart/mozart047.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/mozart/._mozart047.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/mozart/mozart046.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/mozart/._mozart046.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/chopin/chopin054.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/chopin/._chopin054.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/chopin/chopin068.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/chopin/._chopin068.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/chopin/chopin083.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/chopin/._chopin083.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/chopin/chopin097.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/chopin/._chopin097.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/chopin/chopin096.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/chopin/._chopin096.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/chopin/chopin082.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/chopin/._chopin082.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/chopin/chopin055.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/chopin/._chopin055.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/chopin/chopin057.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/chopin/._chopin057.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/chopin/chopin094.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/chopin/._chopin094.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/chopin/chopin080.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/chopin/._chopin080.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/chopin/chopin081.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/chopin/._chopin081.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/chopin/chopin095.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/chopin/._chopin095.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/chopin/chopin056.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/chopin/._chopin056.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/chopin/.DS_Store
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/chopin/._.DS_Store
#   inflating: Composer_Dataset/NN_midi_files_extended/train/chopin/chopin052.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/chopin/._chopin052.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/chopin/chopin091.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/chopin/._chopin091.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/chopin/chopin085.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/chopin/._chopin085.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/chopin/chopin084.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/chopin/._chopin084.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/chopin/chopin090.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/chopin/._chopin090.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/chopin/chopin079.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/chopin/._chopin079.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/chopin/chopin051.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/chopin/._chopin051.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/chopin/chopin092.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/chopin/._chopin092.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/chopin/chopin093.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/chopin/._chopin093.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/chopin/chopin050.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/chopin/._chopin050.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/chopin/chopin075.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/chopin/._chopin075.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/chopin/chopin049.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/chopin/._chopin049.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/chopin/chopin074.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/chopin/._chopin074.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/chopin/chopin060.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/chopin/._chopin060.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/chopin/chopin076.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/chopin/._chopin076.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/chopin/chopin089.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/chopin/._chopin089.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/chopin/chopin088.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/chopin/._chopin088.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/chopin/chopin063.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/chopin/._chopin063.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/chopin/chopin077.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/chopin/._chopin077.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/chopin/chopin073.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/chopin/._chopin073.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/chopin/chopin067.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/chopin/._chopin067.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/chopin/chopin098.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/chopin/._chopin098.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/chopin/chopin072.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/chopin/._chopin072.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/chopin/chopin058.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/chopin/._chopin058.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/chopin/chopin064.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/chopin/._chopin064.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/chopin/chopin071.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/chopin/._chopin071.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/chopin/chopin065.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/chopin/._chopin065.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/chopin/chopin059.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/chopin/._chopin059.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/handel/handel113.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/handel/._handel113.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/handel/handel099.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/handel/._handel099.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/handel/handel138.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/handel/._handel138.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/handel/handel104.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/handel/._handel104.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/handel/handel110.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/handel/._handel110.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/handel/handel111.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/handel/._handel111.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/handel/handel105.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/handel/._handel105.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/handel/handel101.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/handel/._handel101.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/handel/handel115.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/handel/._handel115.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/handel/handel129.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/handel/._handel129.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/handel/.DS_Store
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/handel/._.DS_Store
#   inflating: Composer_Dataset/NN_midi_files_extended/train/handel/handel128.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/handel/._handel128.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/handel/handel114.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/handel/._handel114.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/handel/handel100.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/handel/._handel100.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/handel/handel116.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/handel/._handel116.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/handel/handel102.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/handel/._handel102.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/handel/handel103.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/handel/._handel103.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/handel/handel117.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/handel/._handel117.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/handel/handel148.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/handel/._handel148.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/handel/handel144.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/handel/._handel144.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/handel/handel146.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/handel/._handel146.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/handel/handel143.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/handel/._handel143.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/handel/handel140.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/handel/._handel140.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/handel/handel141.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/handel/._handel141.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/handel/handel132.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/handel/._handel132.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/handel/handel126.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/handel/._handel126.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/handel/handel127.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/handel/._handel127.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/handel/handel133.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/handel/._handel133.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/handel/handel125.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/handel/._handel125.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/handel/handel131.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/handel/._handel131.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/handel/handel130.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/handel/._handel130.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/handel/handel124.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/handel/._handel124.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/handel/handel118.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/handel/._handel118.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/handel/handel120.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/handel/._handel120.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/handel/handel134.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/handel/._handel134.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/handel/handel108.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/handel/._handel108.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/handel/handel109.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/handel/._handel109.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/handel/handel135.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/handel/._handel135.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/handel/handel121.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/handel/._handel121.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/handel/handel123.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/handel/._handel123.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/handel/handel122.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/handel/._handel122.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/handel/handel136.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/handel/._handel136.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/byrd/.DS_Store
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/byrd/._.DS_Store
#   inflating: Composer_Dataset/NN_midi_files_extended/train/byrd/byrd156.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/byrd/._byrd156.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/byrd/byrd195.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/byrd/._byrd195.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/byrd/byrd181.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/byrd/._byrd181.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/byrd/byrd194.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/byrd/._byrd194.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/byrd/byrd157.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/byrd/._byrd157.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/byrd/byrd155.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/byrd/._byrd155.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/byrd/byrd169.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/byrd/._byrd169.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/byrd/byrd182.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/byrd/._byrd182.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/byrd/byrd196.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/byrd/._byrd196.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/byrd/byrd197.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/byrd/._byrd197.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/byrd/byrd183.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/byrd/._byrd183.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/byrd/byrd154.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/byrd/._byrd154.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/byrd/byrd178.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/byrd/._byrd178.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/byrd/byrd187.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/byrd/._byrd187.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/byrd/byrd193.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/byrd/._byrd193.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/byrd/byrd192.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/byrd/._byrd192.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/byrd/byrd186.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/byrd/._byrd186.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/byrd/byrd179.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/byrd/._byrd179.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/byrd/byrd153.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/byrd/._byrd153.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/byrd/byrd190.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/byrd/._byrd190.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/byrd/byrd185.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/byrd/._byrd185.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/byrd/byrd191.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/byrd/._byrd191.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/byrd/byrd177.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/byrd/._byrd177.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/byrd/byrd163.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/byrd/._byrd163.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/byrd/byrd188.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/byrd/._byrd188.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/byrd/byrd189.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/byrd/._byrd189.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/byrd/byrd162.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/byrd/._byrd162.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/byrd/byrd160.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/byrd/._byrd160.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/byrd/byrd149.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/byrd/._byrd149.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/byrd/byrd175.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/byrd/._byrd175.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/byrd/byrd161.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/byrd/._byrd161.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/byrd/byrd159.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/byrd/._byrd159.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/byrd/byrd165.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/byrd/._byrd165.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/byrd/byrd171.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/byrd/._byrd171.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/byrd/byrd170.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/byrd/._byrd170.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/byrd/byrd164.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/byrd/._byrd164.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/byrd/byrd158.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/byrd/._byrd158.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/byrd/byrd172.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/byrd/._byrd172.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/byrd/byrd166.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/byrd/._byrd166.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/byrd/byrd198.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/byrd/._byrd198.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/byrd/byrd167.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/byrd/._byrd167.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/byrd/byrd173.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/byrd/._byrd173.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/schumann/schumann200.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/schumann/._schumann200.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/schumann/schumann214.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/schumann/._schumann214.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/schumann/schumann228.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/schumann/._schumann228.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/schumann/schumann229.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/schumann/._schumann229.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/schumann/schumann215.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/schumann/._schumann215.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/schumann/schumann201.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/schumann/._schumann201.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/schumann/schumann203.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/schumann/._schumann203.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/schumann/schumann202.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/schumann/._schumann202.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/schumann/schumann216.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/schumann/._schumann216.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/schumann/.DS_Store
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/schumann/._.DS_Store
#   inflating: Composer_Dataset/NN_midi_files_extended/train/schumann/schumann212.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/schumann/._schumann212.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/schumann/schumann206.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/schumann/._schumann206.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/schumann/schumann207.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/schumann/._schumann207.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/schumann/schumann213.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/schumann/._schumann213.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/schumann/schumann239.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/schumann/._schumann239.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/schumann/schumann211.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/schumann/._schumann211.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/schumann/schumann210.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/schumann/._schumann210.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/schumann/schumann204.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/schumann/._schumann204.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/schumann/schumann199.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/schumann/._schumann199.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/schumann/schumann242.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/schumann/._schumann242.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/schumann/schumann241.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/schumann/._schumann241.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/schumann/schumann221.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/schumann/._schumann221.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/schumann/schumann235.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/schumann/._schumann235.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/schumann/schumann208.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/schumann/._schumann208.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/schumann/schumann234.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/schumann/._schumann234.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/schumann/schumann236.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/schumann/._schumann236.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/schumann/schumann222.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/schumann/._schumann222.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/schumann/schumann223.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/schumann/._schumann223.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/schumann/schumann237.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/schumann/._schumann237.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/schumann/schumann233.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/schumann/._schumann233.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/schumann/schumann227.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/schumann/._schumann227.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/schumann/schumann226.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/schumann/._schumann226.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/schumann/schumann232.mid
# ...
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/bach/._bach391.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/bach/bach385.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/bach/._bach385.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/bach/bach352.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/bach/._bach352.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/bach/bach346.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/bach/._bach346.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/bach/bach347.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/bach/._bach347.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/bach/bach353.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/bach/._bach353.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/bach/bach390.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/bach/._bach390.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/bartok/bartok426.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/bartok/._bartok426.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/bartok/bartok432.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/bartok/._bartok432.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/bartok/bartok397.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/bartok/._bartok397.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/bartok/bartok396.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/bartok/._bartok396.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/bartok/bartok433.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/bartok/._bartok433.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/bartok/bartok427.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/bartok/._bartok427.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/bartok/bartok419.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/bartok/._bartok419.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/bartok/bartok431.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/bartok/._bartok431.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/bartok/bartok425.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/bartok/._bartok425.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/bartok/bartok394.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/bartok/._bartok394.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/bartok/bartok395.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/bartok/._bartok395.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/bartok/bartok430.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/bartok/._bartok430.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/bartok/bartok418.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/bartok/._bartok418.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/bartok/.DS_Store
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/bartok/._.DS_Store
#   inflating: Composer_Dataset/NN_midi_files_extended/train/bartok/bartok420.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/bartok/._bartok420.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/bartok/bartok408.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/bartok/._bartok408.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/bartok/bartok409.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/bartok/._bartok409.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/bartok/bartok421.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/bartok/._bartok421.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/bartok/bartok435.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/bartok/._bartok435.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/bartok/bartok423.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/bartok/._bartok423.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/bartok/bartok437.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/bartok/._bartok437.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/bartok/bartok393.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/bartok/._bartok393.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/bartok/bartok436.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/bartok/._bartok436.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/bartok/bartok422.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/bartok/._bartok422.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/bartok/bartok440.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/bartok/._bartok440.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/bartok/bartok407.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/bartok/._bartok407.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/bartok/bartok413.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/bartok/._bartok413.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/bartok/bartok406.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/bartok/._bartok406.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/bartok/bartok404.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/bartok/._bartok404.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/bartok/bartok405.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/bartok/._bartok405.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/bartok/bartok411.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/bartok/._bartok411.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/bartok/bartok439.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/bartok/._bartok439.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/bartok/bartok415.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/bartok/._bartok415.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/bartok/bartok401.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/bartok/._bartok401.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/bartok/bartok398.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/bartok/._bartok398.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/bartok/bartok399.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/bartok/._bartok399.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/bartok/bartok428.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/bartok/._bartok428.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/bartok/bartok414.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/bartok/._bartok414.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/bartok/bartok402.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/bartok/._bartok402.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/bartok/bartok416.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/bartok/._bartok416.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/bartok/bartok417.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/bartok/._bartok417.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/train/bartok/bartok403.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/train/bartok/._bartok403.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/dev/mozart/.DS_Store
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/dev/mozart/._.DS_Store
#   inflating: Composer_Dataset/NN_midi_files_extended/dev/mozart/mozart039.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/dev/mozart/._mozart039.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/dev/mozart/mozart035.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/dev/mozart/._mozart035.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/dev/mozart/mozart020.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/dev/mozart/._mozart020.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/dev/mozart/mozart040.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/dev/mozart/._mozart040.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/dev/chopin/chopin069.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/dev/chopin/._chopin069.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/dev/chopin/.DS_Store
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/dev/chopin/._.DS_Store
#   inflating: Composer_Dataset/NN_midi_files_extended/dev/chopin/chopin087.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/dev/chopin/._chopin087.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/dev/chopin/chopin061.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/dev/chopin/._chopin061.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/dev/chopin/chopin070.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/dev/chopin/._chopin070.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/dev/handel/handel106.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/dev/handel/._handel106.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/dev/handel/handel139.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/dev/handel/._handel139.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/dev/handel/.DS_Store
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/dev/handel/._.DS_Store
#   inflating: Composer_Dataset/NN_midi_files_extended/dev/handel/handel145.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/dev/handel/._handel145.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/dev/handel/handel119.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/dev/handel/._handel119.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/dev/byrd/.DS_Store
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/dev/byrd/._.DS_Store
#   inflating: Composer_Dataset/NN_midi_files_extended/dev/byrd/byrd180.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/dev/byrd/._byrd180.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/dev/byrd/byrd168.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/dev/byrd/._byrd168.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/dev/byrd/byrd184.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/dev/byrd/._byrd184.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/dev/byrd/byrd152.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/dev/byrd/._byrd152.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/dev/schumann/schumann217.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/dev/schumann/._schumann217.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/dev/schumann/.DS_Store
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/dev/schumann/._.DS_Store
#   inflating: Composer_Dataset/NN_midi_files_extended/dev/schumann/schumann238.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/dev/schumann/._schumann238.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/dev/schumann/schumann209.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/dev/schumann/._schumann209.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/dev/mendelssohn/mendelssohn262.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/dev/mendelssohn/._mendelssohn262.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/dev/mendelssohn/.DS_Store
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/dev/mendelssohn/._.DS_Store
#   inflating: Composer_Dataset/NN_midi_files_extended/dev/mendelssohn/mendelssohn265.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/dev/mendelssohn/._mendelssohn265.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/dev/mendelssohn/mendelssohn258.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/dev/mendelssohn/._mendelssohn258.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/dev/mendelssohn/mendelssohn270.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/dev/mendelssohn/._mendelssohn270.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/dev/hummel/hummel312.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/dev/hummel/._hummel312.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/dev/hummel/.DS_Store
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/dev/hummel/._.DS_Store
#   inflating: Composer_Dataset/NN_midi_files_extended/dev/hummel/hummel303.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/dev/hummel/._hummel303.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/dev/hummel/hummel301.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/dev/hummel/._hummel301.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/dev/hummel/hummel327.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/dev/hummel/._hummel327.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/dev/bach/bach348.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/dev/bach/._bach348.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/dev/bach/.DS_Store
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/dev/bach/._.DS_Store
#   inflating: Composer_Dataset/NN_midi_files_extended/dev/bach/bach354.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/dev/bach/._bach354.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/dev/bach/bach344.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/dev/bach/._bach344.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/dev/bach/bach384.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/dev/bach/._bach384.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/dev/bartok/bartok424.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/dev/bartok/._bartok424.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/dev/bartok/.DS_Store
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/dev/bartok/._.DS_Store
#   inflating: Composer_Dataset/NN_midi_files_extended/dev/bartok/bartok434.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/dev/bartok/._bartok434.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/dev/bartok/bartok412.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/dev/bartok/._bartok412.mid
#   inflating: Composer_Dataset/NN_midi_files_extended/dev/bartok/bartok410.mid
#   inflating: __MACOSX/Composer_Dataset/NN_midi_files_extended/dev/bartok/._bartok410.mid

# %%
import os
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
import pretty_midi

# %%
def extract_features(midi_data):
    # Tempo
    tempo_changes = midi_data.get_tempo_changes()
    tempo = np.mean(tempo_changes[1]) if len(tempo_changes[1]) > 0 else 120.0

    # Key signature
    key_number = midi_data.key_signature_changes[0].key_number if midi_data.key_signature_changes else -1

    # Notes
    notes = []
    for instrument in midi_data.instruments:
        if not instrument.is_drum:
            for note in instrument.notes:
                notes.append(note.pitch)

    avg_pitch = np.mean(notes) if notes else 0
    min_pitch = np.min(notes) if notes else 0
    max_pitch = np.max(notes) if notes else 0

    # Note density
    duration = midi_data.get_end_time()
    note_density = len(notes) / duration if duration > 0 else 0

    # Normalize features
    tempo /= 300.0
    avg_pitch /= 127.0
    min_pitch /= 127.0
    max_pitch /= 127.0
    note_density /= 10.0
    key_number = (key_number + 1) / 12.0

    return np.array([tempo, avg_pitch, min_pitch, max_pitch, note_density, key_number], dtype=np.float32)

# %%
# !pip install pretty_midi
# Out:
# Collecting pretty_midi
#   Downloading pretty_midi-0.2.10.tar.gz (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 53.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from pretty_midi) (2.0.2)
# Collecting mido>=1.1.16 (from pretty_midi)
#   Downloading mido-1.3.3-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from pretty_midi) (1.17.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from mido>=1.1.16->pretty_midi) (25.0)
# Downloading mido-1.3.3-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 kB 5.5 MB/s eta 0:00:00
# Building wheels for collected packages: pretty_midi
#   Building wheel for pretty_midi (setup.py) ... done
#   Created wheel for pretty_midi: filename=pretty_midi-0.2.10-py3-none-any.whl size=5592286 sha256=7fff170a0c5743f791cd51bb3a2cd6af3ae03d90583741fc25a0f6aace8a0068
#   Stored in directory: /root/.cache/pip/wheels/e6/95/ac/15ceaeb2823b04d8e638fd1495357adb8d26c00ccac9d7782e
# Successfully built pretty_midi
# Installing collected packages: mido, pretty_midi
# Successfully installed mido-1.3.3 pretty_midi-0.2.10

# %%
class MidiDataset(Dataset):
    def __init__(self, file_paths, labels, max_seq_len=500, fs=10, augment=True):
        self.file_paths = file_paths
        self.labels = labels
        self.max_seq_len = max_seq_len
        self.fs = fs
        self.augment = augment

    def __len__(self):
        return len(self.file_paths)

    def __getitem__(self, idx):
        midi_path = self.file_paths[idx]
        label = self.labels[idx]

        midi_data = pretty_midi.PrettyMIDI(midi_path)

        # Augmentation: Random transpose
        if self.augment and np.random.rand() < 0.5:
            semitones = np.random.randint(-4, 5)
            for instrument in midi_data.instruments:
                for note in instrument.notes:
                    note.pitch = min(max(note.pitch + semitones, 0), 127)

        # Piano roll for CNN
        piano_roll = midi_data.get_piano_roll(fs=self.fs)
        if piano_roll.shape[1] > self.max_seq_len:
            piano_roll = piano_roll[:, :self.max_seq_len]
        else:
            pad_width = self.max_seq_len - piano_roll.shape[1]
            piano_roll = np.pad(piano_roll, ((0, 0), (0, pad_width)), mode='constant')
        piano_roll = (piano_roll > 0).astype(np.float32)

        # Note sequence for LSTM
        notes = []
        for instrument in midi_data.instruments:
            if not instrument.is_drum:
                for note in instrument.notes:
                    notes.append(note.pitch)
        if len(notes) > self.max_seq_len:
            notes = notes[:self.max_seq_len]
        else:
            notes += [0] * (self.max_seq_len - len(notes))

        # Extract numeric features
        numeric_features = extract_features(midi_data)

        return (
            torch.tensor(piano_roll, dtype=torch.float32),
            torch.tensor(notes, dtype=torch.long),
            torch.tensor(numeric_features, dtype=torch.float32),
            torch.tensor(label, dtype=torch.long)
        )

# %%
def load_file_paths(root_dir):
    splits = ['train', 'dev', 'test']
    data = {}
    for split in splits:
        split_dir = os.path.join(root_dir, split)
        file_paths, labels = [], []
        composers = [c for c in sorted(os.listdir(split_dir)) if os.path.isdir(os.path.join(split_dir, c))]
        composer_to_idx = {composer: idx for idx, composer in enumerate(composers)}

        for composer in composers:
            composer_dir = os.path.join(split_dir, composer)
            for file in os.listdir(composer_dir):
                if file.endswith(('.mid', '.midi')):
                    file_paths.append(os.path.join(composer_dir, file))
                    labels.append(composer_to_idx[composer])

        data[split] = {'files': file_paths, 'labels': labels, 'composer_to_idx': composer_to_idx}
    return data

root_dir = '/content/Composer_Dataset/NN_midi_files_extended/'
dataset_info = load_file_paths(root_dir)

train_dataset = MidiDataset(dataset_info['train']['files'], dataset_info['train']['labels'], augment=True)
dev_dataset = MidiDataset(dataset_info['dev']['files'], dataset_info['dev']['labels'], augment=False)
test_dataset = MidiDataset(dataset_info['test']['files'], dataset_info['test']['labels'], augment=False)

train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
dev_loader = DataLoader(dev_dataset, batch_size=16)
test_loader = DataLoader(test_dataset, batch_size=16)

# %%
class ComposerClassifier(nn.Module):
    def __init__(self, num_classes):
        super(ComposerClassifier, self).__init__()

        # CNN for piano roll
        self.cnn = nn.Sequential(
            nn.Conv2d(1, 16, kernel_size=(3, 3), padding=1),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.MaxPool2d((2, 2)),
            nn.Conv2d(16, 32, kernel_size=(3, 3), padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d((2, 2))
        )
        self.cnn_fc = nn.Sequential(
            nn.Linear(32 * (128 // 4) * (500 // 4), 128),
            nn.LayerNorm(128),
            nn.ReLU()
        )

        # LSTM for note sequences
        self.embedding = nn.Embedding(128, 64)
        self.lstm = nn.LSTM(64, 128, batch_first=True)

        # Fully connected
        self.fc = nn.Sequential(
            nn.Linear(128 + 128 + 6, 128),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(64, num_classes)
        )

    def forward(self, piano_roll, note_seq, numeric_features):
        # CNN branch
        x_cnn = piano_roll.unsqueeze(1)
        x_cnn = self.cnn(x_cnn)
        x_cnn = x_cnn.view(x_cnn.size(0), -1)
        x_cnn = self.cnn_fc(x_cnn)

        # LSTM branch
        x_embed = self.embedding(note_seq)
        _, (h_n, _) = self.lstm(x_embed)
        x_lstm = h_n[-1]

        # Combine
        x = torch.cat((x_cnn, x_lstm, numeric_features), dim=1)
        return self.fc(x)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
num_classes = len(dataset_info['train']['composer_to_idx'])

model = ComposerClassifier(num_classes).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0003, weight_decay=1e-5)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', factor=0.5, patience=3)

epochs = 80
best_val_acc = 0
patience = 15
wait = 0

for epoch in range(epochs):
    model.train()
    total_loss = 0
    for piano_roll, note_seq, numeric_features, labels in train_loader:
        piano_roll, note_seq, numeric_features, labels = (
            piano_roll.to(device), note_seq.to(device),
            numeric_features.to(device), labels.to(device)
        )
        optimizer.zero_grad()
        outputs = model(piano_roll, note_seq, numeric_features)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()

    avg_loss = total_loss / len(train_loader)

    # Validation
    model.eval()
    correct, total = 0, 0
    with torch.no_grad():
        for piano_roll, note_seq, numeric_features, labels in dev_loader:
            piano_roll, note_seq, numeric_features, labels = (
                piano_roll.to(device), note_seq.to(device),
                numeric_features.to(device), labels.to(device)
            )
            outputs = model(piano_roll, note_seq, numeric_features)
            _, predicted = torch.max(outputs, 1)
            correct += (predicted == labels).sum().item()
            total += labels.size(0)
    val_acc = 100 * correct / total
    scheduler.step(val_acc)

    print(f"Epoch [{epoch+1}/{epochs}], Loss: {avg_loss:.4f}, Val Acc: {val_acc:.2f}%")

    # Early stopping
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save(model.state_dict(), "best_model.pth")
        wait = 0
    else:
        wait += 1
        if wait >= patience:
            print("Early stopping triggered!")
            break

# Test evaluation
model.load_state_dict(torch.load("best_model.pth"))
model.eval()
correct, total = 0, 0
with torch.no_grad():
    for piano_roll, note_seq, numeric_features, labels in test_loader:
        piano_roll, note_seq, numeric_features, labels = (
            piano_roll.to(device), note_seq.to(device),
            numeric_features.to(device), labels.to(device)
        )
        outputs = model(piano_roll, note_seq, numeric_features)
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == labels).sum().item()
        total += labels.size(0)

print(f"Test Accuracy: {100 * correct / total:.2f}%")
# Out:
# /usr/local/lib/python3.11/dist-packages/pretty_midi/pretty_midi.py:100: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(
# Epoch [1/80], Loss: 2.2075, Val Acc: 11.43%
# Epoch [2/80], Loss: 2.1947, Val Acc: 25.71%
# Epoch [3/80], Loss: 2.1782, Val Acc: 31.43%
# Epoch [4/80], Loss: 2.1545, Val Acc: 31.43%
# Epoch [5/80], Loss: 2.0982, Val Acc: 48.57%
# Epoch [6/80], Loss: 1.9946, Val Acc: 51.43%
# Epoch [7/80], Loss: 1.7831, Val Acc: 48.57%
# Epoch [8/80], Loss: 1.5706, Val Acc: 57.14%
# Epoch [9/80], Loss: 1.4144, Val Acc: 57.14%
# Epoch [10/80], Loss: 1.2161, Val Acc: 54.29%
# Epoch [11/80], Loss: 0.9262, Val Acc: 45.71%
# Epoch [12/80], Loss: 0.8118, Val Acc: 60.00%
# Epoch [13/80], Loss: 0.6187, Val Acc: 60.00%
# Epoch [14/80], Loss: 0.4890, Val Acc: 48.57%
# Epoch [15/80], Loss: 0.3033, Val Acc: 51.43%
# Epoch [16/80], Loss: 0.2109, Val Acc: 45.71%
# Epoch [17/80], Loss: 0.2446, Val Acc: 51.43%
# Epoch [18/80], Loss: 0.2697, Val Acc: 51.43%
# Epoch [19/80], Loss: 0.1451, Val Acc: 40.00%
# Epoch [20/80], Loss: 0.1110, Val Acc: 54.29%
# Epoch [21/80], Loss: 0.0829, Val Acc: 51.43%
# Epoch [22/80], Loss: 0.1002, Val Acc: 51.43%
# Epoch [23/80], Loss: 0.0985, Val Acc: 48.57%
# Epoch [24/80], Loss: 0.0823, Val Acc: 51.43%
# Epoch [25/80], Loss: 0.0721, Val Acc: 51.43%
# Epoch [26/80], Loss: 0.1190, Val Acc: 45.71%
# Epoch [27/80], Loss: 0.0884, Val Acc: 51.43%
# Early stopping triggered!
# Test Accuracy: 68.57%
